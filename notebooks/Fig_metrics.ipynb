# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.plotting_utils import show_metrics
# Out:
# Pysteps configuration file found at: /home/users/par55/.local/lib/python3.10/site-packages/pysteps/pystepsrc

# %%
# Set paths
metrics_file_path = '../pretrained_models/outputs/metrics_trained_models.pkl'
output_path = '../outputs/'

# %%
# Read in metrics
metrics = pd.read_pickle(metrics_file_path)
# Drop U V, plotting wind speed only
metrics= metrics[metrics['var']!='U10']
metrics = metrics[metrics['var']!='V10']

# %%
show_metrics(metrics, output_path)
