# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.plotting_utils import show_freq_distrib
# Out:
# Pysteps configuration file found at: /home/users/par55/.local/lib/python3.10/site-packages/pysteps/pystepsrc

# %%
# Set paths
freq_distr_file_path = '../pretrained_models/outputs/freq_distribution_trained_models.pkl'
output_path = '../outputs/'

# %%
# Read in metrics
freq_df = pd.read_pickle(freq_distr_file_path)
# Drop U V, plotting wind speed only
freq_df = freq_df[freq_df['variable'] != 'U10']
freq_df = freq_df[freq_df['variable'] != 'V10']
# Plot Figure of frequency distribution
show_freq_distrib(freq_df, output_dir=output_path)
